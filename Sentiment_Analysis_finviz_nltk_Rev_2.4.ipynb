# %% [markdown]
# Instructions:
#
# Some things you must know before using this app.:
#
#     -This app helps survey the most recent 100 posts or titles that appear on the finviz.com website for a particular stock symbol. Much thanks to the Python Project for sharing their code in how to scrape the website and the use of nltk's Vader sentiment analyzer to provide the sentiment ratings for each of the titles. The visual summary in the form of a bar chart is also great. The link to the Youtube video is provided below.
#
# [Python Project] Sentiment Analysis and Visualization of Stock News - YouTube https://www.youtube.com/watch?v=o-zM8onpQZY
#
#     -The sentiment analyzer that is used is an industry standard but it is not perfect. You will find titles that appear to have their sentiments mis-rated.
#
#     -This is NOT a stock picker nor is it intended to provide any information on a company's or stock prices' future, present or past performance. Any conclusions made from the information contained here-in are the sole responsibility of the user.
#
#     -The information contained here-in is not exhaustive and should not be treated as such.
#
#     -The accuracy of the information contained here-in is not verified. It could be wrong.
#
#     -This application assumes a rudimentry understanding of the jupyter notebook environment. If you have absolutely no technical background, find someone who does and who is willing to help you. It may save you hours of frustration.
#
# To use this app.:
#
#     Run the cell titled "RUN THIS CELL" by selecting this cell (side bar will be blue) and pressing the Run button on the toolbar above (in the jupyter notebook environment there are other ways to run the code.)
#
#     Enter the stock symbol (not the company's name) you want to research. (It is not case sensitive.)
#
#     After you have entered the stock symbol you will be prompted to see if you want to remove what are known as stopwords. Stopwords are words that are generally accepted as conveying no sentiment. If you choose to have them removed it might make the the code run more efficiently.
#
#     You should see a bar chart with the sentiment values for the most recent 100 articles with date listed on the x-axis and the nltk's VADER sentiment value on the y-axis. If no bar chart appears run through the all of the prompts and re-start the app.
#
#     Next you will see a pie chart that is divided into "positive," "neutral," and "negative" sentiments and the accompanied statistics.
#
#     Following this you will see a word cloud of the titles with postive sentiment.
#
#     To find the posts where these words reside, type in the word in the prompt. These are case sentitive so if your search comes back empty, re-enter the word with changed capitization. For example, start with the first letter of the word capitalized with the rest of the letters in lower case. If that does not yield anything, try all lower case. Make sure your spelling is exactly what is represented in the word cloud. Enter only one word at the prompt.
#
#     If you don't want to search on any of the key words, just press "enter" when asked what word to search on.
#
#     Next you will see the word cloud for the neutral sentiment titles. Follow the same procedure as above to search or move on.
#
#     Next you will see the word cloud for the negative sentiment titles. You have the same opportunity to search titles that have negative sentiments.
#
#     When the program is finished, the message "All done ..." will appear.

# %% [markdown]
# Rev 1 incorporates simple statistics and sorting based on nltk sentiment ratings. si
#
# Rev 2 incorporates stopwords removal and then plots word clouds based on sentiment ratings.; adds pie chart; search titles
# using key word. si
#
# Rev 2.1 changes in the structure of the program. encorporates methods and main into one cell for easier execution.
#
# Rev 2.2 - makes the input fields more robust to aberrant inputs
#         - changes "no" to "n" in another key word search request
#         - incoporates the loading of the libraries into the main body for ease of execution
#         - adds instructions for running the application
#
# Rev 2.3 - add capability to remove stopwords from the titles
#         - added histogram of sentiment values from the 100 articles (JI)
#         - added handling of empty article list for word cloud (if there are no articles, the word cloud is not made)
#
# Rev 2.4 - adds actionable links to the titles of the blogs
#         - increases the sizes of the charts and histograms
#         - improves instructions for inputs

# %%
#Title: RUN THIS CELL

from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time

from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords

nltk.download('vader_lexicon')
nltk.download('punkt')
nltk.download('stopwords')
stopWords = set(stopwords.words('english'))

#### METHODS ####

def remove_stopwords(): #provides a comprehensive list of stopwords; returns 'stopWords'

    #440
    from nltk.tokenize import sent_tokenize, word_tokenize
    from nltk.corpus import stopwords

    #450
    stopWords = set(stopwords.words('english'))

    #470 creates a list of new stopwords and then adds them to the set provided by nltk
    # Note: it is case sensitive

    newStopWords = ['a', 'about', 'above', 'across', 'after', 'afterwards']
    newStopWords += ['again', 'against', 'all', 'almost', 'alone', 'along']
    newStopWords += ['already', 'also', 'although', 'always', 'am', 'among']
    newStopWords += ['amongst', 'amoungst', 'amount', 'an', 'and', 'another']
    newStopWords += ['any', 'anyhow', 'anyone', 'anything', 'anyway', 'anywhere']
    newStopWords += ['are', 'around', 'as', 'at', 'back', 'be', 'became']
    newStopWords += ['because', 'become', 'becomes', 'becoming', 'been']
    newStopWords += ['before', 'beforehand', 'behind', 'being', 'below']
    newStopWords += ['beside', 'besides', 'between', 'beyond', 'bill', 'both']
    newStopWords += ['bottom', 'but', 'by', 'call', 'can', 'cannot', 'cant']
    newStopWords += ['co', 'computer', 'con', 'could', 'couldnt', 'cry', 'de']
    newStopWords += ['describe', 'detail', 'did', 'do', 'done', 'down', 'due']
    newStopWords += ['during', 'each', 'eg', 'eight', 'either', 'eleven', 'else']
    newStopWords += ['elsewhere', 'empty', 'enough', 'etc', 'even', 'ever']
    newStopWords += ['every', 'everyone', 'everything', 'everywhere', 'except']
    newStopWords += ['few', 'fifteen', 'fifty', 'fill', 'find', 'fire', 'first']
    newStopWords += ['five', 'for', 'former', 'formerly', 'forty', 'found']
    newStopWords += ['four', 'from', 'front', 'full', 'further', 'get', 'give']
    newStopWords += ['go', 'had', 'has', 'hasnt', 'have', 'he', 'hence', 'her']
    newStopWords += ['here', 'hereafter', 'hereby', 'herein', 'hereupon', 'hers']
    newStopWords += ['herself', 'him', 'himself', 'his', 'how', 'however']
    newStopWords += ['hundred', 'i', 'ie', 'if', 'in', 'inc', 'indeed']
    newStopWords += ['interest', 'into', 'is', 'it', 'its', 'itself', 'keep']
    newStopWords += ['last', 'latter', 'latterly', 'least', 'less', 'ltd', 'made']
    newStopWords += ['many', 'may', 'me', 'meanwhile', 'might', 'mill', 'mine']
    newStopWords += ['more', 'moreover', 'most', 'mostly', 'move', 'much']
    newStopWords += ['must', 'my', 'myself', 'name', 'namely', 'neither', 'never']
    newStopWords += ['nevertheless', 'next', 'nine', 'nobody', 'none'] #removed 'no'
    newStopWords += ['noone', 'nor', 'not', 'nothing', 'now', 'nowhere', 'of']
    newStopWords += ['off', 'often', 'on','once', 'one', 'only', 'onto', 'or']
    newStopWords += ['other', 'others', 'otherwise', 'our', 'ours', 'ourselves']
    newStopWords += ['out', 'over', 'own', 'part', 'per', 'perhaps', 'please']
    newStopWords += ['put', 'rather', 're', 's', 'same', 'see', 'seem', 'seemed']
    newStopWords += ['seeming', 'seems', 'serious', 'several', 'she', 'should']
    newStopWords += ['show', 'side', 'since', 'sincere', 'six', 'sixty', 'so']
    newStopWords += ['some', 'somehow', 'someone', 'something', 'sometime']
    newStopWords += ['sometimes', 'somewhere', 'still', 'such', 'system', 'take']
    newStopWords += ['ten', 'than', 'that', 'the', 'their', 'them', 'themselves']
    newStopWords += ['then', 'thence', 'there', 'thereafter', 'thereby']
    newStopWords += ['therefore', 'therein', 'thereupon', 'these', 'they']
    newStopWords += ['thick', 'thin', 'third', 'this', 'those', 'though', 'three']
    newStopWords += ['three', 'through', 'throughout', 'thru', 'thus', 'to']
    newStopWords += ['together', 'too', 'top', 'toward', 'towards', 'twelve']
    newStopWords += ['twenty', 'two', 'un', 'under', 'until', 'up', 'upon']
    newStopWords += ['us', 'very', 'via', 'was', 'we', 'well', 'were', 'what']
    newStopWords += ['whatever', 'when', 'whence', 'whenever', 'where']
    newStopWords += ['whereafter', 'whereas', 'whereby', 'wherein', 'whereupon']
    newStopWords += ['wherever', 'whether', 'which', 'while', 'whither', 'who']
    newStopWords += ['whoever', 'whole', 'whom', 'whose', 'why', 'will', 'with']
    newStopWords += ['within', 'without', 'would', 'yet', 'you', 'your']
    newStopWords += ['yours', 'yourself', 'yourselves'] #provided by Codecademy??

    # additional stopwords:
    newStopWords += ['[Screenshot]', '[screenshot]', 'Screenshot', '[Screenshot]Great', '[SCREENSHOT]', 'screenshot', 
                 'The', 'the', 'SMART', 'yah', 'got', 'nutty', 'moving', 'weeks', 'Got', 'So', 'today', 'Been', 'or',
                    "n't"]

    newStopWords += ['I', 'it', 'It'] # pronouns

    newStopWords += ['AMD', 'NVDA','NVDA', 'TSLA', 'GOOG', 'BA', 'FB', 'GOOGL', 'INTC', 'intel', 'Intel', 'CSCO', 'MU', 
                 'SMH', 'TSM','AAPL', 'TSLA', 'CSCO', 'POETF', 'PHOTONICS', 'DD', 'ARWR', 'T', 'INFI', 'AMC', 'ARK',
                'GME', 'NIO', 'QS', 'ADBE', 'MSFT'] # Stock symbols or names

    newStopWords += ['Readytogo123', 'Maddog68','Stocktwits'] # nouns

    newStopWords += ['.', '?', '!', ';', ',', "'"] # punctuation

    newStopWords += ['&', '#', '%', '$', '@'] # symbols

    newStopWords += ['41.75', '530.05', '39', 'Two', 'two',] # numbers

    #adds them to the stopWords list provided by nltk
    for i in newStopWords:
        stopWords.add(i) #stopWords is defined as a "set" in #450 when inputed as english words from nltk;
        # sets cannot be ordered so it must be converted back to a list to be ordered or alphabetized. A set has no duplicate elements.

    #converts the set to a list
    stopWords_list = list(stopWords)

    #sorts the stopword list
    stopWords_list.sort(key = lambda k : k.lower())
    #print(stopWords_list)
    
    #480 This removes words from the list of stopwords and writes list to csv file
    # https://stackoverflow.com/questions/29771168/how-to-remove-words-from-a-list-in-python#:~:text=one%20more%20easy%20way%20to%20remove%20words%20from,%3D%20words%20-%20stopwords%20final_list%20%3D%20list%20%28final_list%29
    #new_words = list(filter(lambda w: w not in stop_words, initial_words))

    WordsToBeRem = ['no'] #words to be removed from the stopword_list
    stopWords = list(filter(lambda w: w not in WordsToBeRem, stopWords_list)) #stopWords_list has been sorted in #470

    #converts the stopword list to a df and then outputs the df to a csv file
    #df_stopwords = pd.DataFrame(stopWords, columns = ['stopwords'])
    #df_stopwords.to_csv('stopwords.csv', index = False) #writes the csv file
    
    return stopWords

def remove(df, stopWords): #returns a df where the stopwords are removed

    dfScrubbed = df.copy() #This is a deep copy. df.copy(deep = True); deep = True is default

    i = 0
    
    while i < len(df):
    
        data = df.iloc[i,1] #column #1 holds the titles of the posts
        words = word_tokenize(data) #the title is separated into individual words (tokenized)
        wordsFiltered = []

        for w in words:
            if w not in stopWords:
                wordsFiltered.append(w)
    
        joinedWordsFiltered = ' '.join(wordsFiltered) #combines the individual words into one string
    
        dfScrubbed.iloc[i,1] = joinedWordsFiltered # replaces the recorded in dfAPIScrubbed with the stopWords removed
        #from the 'body'
    
        i += 1
    
    #print(wordsFiltered)

    #print(dfScrubbed.head())

    return(dfScrubbed)

def wc(df): #creates the word cloud
    #from wordcloud import WordCloud, STOPWORDS 
    from wordcloud import WordCloud
    import matplotlib.pyplot as plt 
    import pandas as pd 

    stopwords = set(stopWords) 
    words = ''
    for review in df.title:
        tokens = str(review).split()
        tokens = [i.lower() for i in tokens]
    
        words += ' '.join(tokens) + ' '
    
    wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(words) 
  
    # plot the WordCloud image                        
    plt.figure(figsize = (8, 8), facecolor = None) 
    plt.imshow(wordcloud) 
    plt.axis("off") 
    plt.tight_layout(pad = 0) 
  
    plt.show() 

def kw(df,keyword): # searches a string for key words; if found will print out the date and title
    i = 0
    #print(df.head(), '188')

    while i < len(df):
    
        data = df.iloc[i,1] #column #1 holds the titles of the posts
        a_bool = keyword in data

        if a_bool == True:
            print(df.iloc[i,0], df.iloc[i,1])
            print(df.iloc[i,2], '\n')
        
        i += 1

def search_repeat(df): # provides opportunity to do multiple searches on key words. returns only the appropriate yes or no response.
    key_word = input('What is the key word you want to search? [press "enter" for none] ')
    print()
    if key_word:
        kw(df, key_word)
        answer = input('Do you want to do another search? [Enter either a "y" or "n."]')
    else:
        answer = 'no' #if there is not key word that is entered it sets answer to no. - assumes if there is no key word there is no desire to do another search.
    while answer not in yes_answer and answer not in no_answer: # Restricts answer to be either in the yes or no list by continuous looping on it unit input matches either list
        answer = error() # prompts for the correct yes or no response. The correct responses are in the yes_answer list and no_answer list.
    return answer

def error(): # provides user the opportunity to correct the user's input
    correction = input('Your input needs to be either a "y" or a "n". Would you like to do another search?')
    return correction

def error1(): # provides user the opportunity to correct the user's input
    correction = input('Your input needs to be either a "y" or a "n". Would you like to remove the stopwords from the titles?')
    return correction

def stopwords_yes_no(): # provides opportunity to removes stopwords from the titles. returns only the appropriate yes or no response.
    yes_no = input('Do you want to remove the stopwords from the titles? [press "enter" for no]')
    if yes_no in yes_answer:
        answer = 'yes'
    else:
        answer = 'no' #if there is not key word that is entered it sets answer to no. - assumes if there is no key word there is no desire to do another search.
    while answer not in yes_answer and answer not in no_answer: # Restricts answer to be either in the yes or no list by continuous looping on it unit input matches either list
        answer = error1() # prompts for the correct yes or no response. The correct responses are in the yes_answer list and no_answer list.
    return answer

################################################################################
#### MAIN ####
################################################################################

yes_answer = ['yes','YES','Yes','y','Y']
no_answer = ['no', 'NO', 'No', 'n', 'N']

symbol = input('What is the symbol of the stock? (Please enter only one.) ')

#### SCRAPES FINVIZ

finviz_url = 'https://www.finviz.com/quote.ashx?t='
#tickers = ['NVDA', 'SLV', 'MU']
tickers = [symbol]

news_tables = {}

for ticker in tickers:
    url = finviz_url + ticker
    
    req = Request(url = url, headers = {'user-agent': 'my-app'})
    response = urlopen(req)
    
    html = BeautifulSoup(response, 'html')
    news_table = html.find(id = 'news-table') # in html : id = "news-table"; line # 551
    news_tables[ticker] = news_table
    
parsed_data = []

for ticker, news_table in news_tables.items():
    for row in news_table.findAll('tr'):
        
        title = row.a.get_text()
        link = row.a.get('href') #captures the link    
        date_data = row.td.text.split(' ')
        
        if len(date_data) == 1: # if there is both a date and time it parses them into two columns
            time = date_data[0]
        else: 
            date = date_data[0] 
            time = date_data[1]
        parsed_data.append([ticker, date, time, title, link])
        
df = pd.DataFrame(parsed_data, columns = ['ticker', 'date', 'time', 'title', 'link'])

#### REMOVES STOPWORDS

sw_answer = stopwords_yes_no() #returns either a 'yes' or 'no' from the user's input
if sw_answer == 'yes':
    stopWords = remove_stopwords() #provides a comprehensive list of stopwords; returns 'stopWords'
    dfScrubbed = remove(df, stopWords) #returns a df where the stopwords are removed
    print('\nThe stopwords will be removed. \n')

#### PERFORMS THE VADER SENTIMENT ANALYSIS.
vader = SentimentIntensityAnalyzer()

f = lambda title: vader.polarity_scores(title)['compound']

if sw_answer == 'yes': #uses dfScrubbed to generate sentiment values if uses said yes
    df['compound'] = dfScrubbed['title'].apply(f) # uses the scrubbed title data to generate the sentiment score and places the result back into the non-scrubbed df
else:
    df['compound'] = df['title'].apply(f) # does not uses the scrubbed titles to produce the sentiment values

#### PLOTS SENTIMENT VALUES AS A FUNCTION OF DATES
df ['date'] = pd.to_datetime(df.date).dt.date        
        
plt.figure(figsize = (10 ,8))

mean_df = df.groupby(['ticker', 'date']).mean()
mean_df = mean_df.unstack()
mean_df = mean_df.xs('compound', axis = 'columns').transpose()

mean_df.plot(kind = 'bar')

print(tickers)

fig = plt.gcf()
fig.set_size_inches(20,10) #adjusts bar chart's size
plt.show()

import time

time.sleep(1.0)

#### PROVIDES DATE RANGES AND SIMPLE STATISTICS ON THE SENTIMENT OF THE TITLES

# provides date ranges for the last 100 articles; 
print('Date Range of the 100 most recent articles: ') 
print('Most Recent Article Date: ', df.iloc[0,1])  
oldest = len(df) - 1
print('Oldest Article Date: ', df.iloc[oldest,1], '\n')

# provides basic sentiment statistics; 
i = 0 # set starting index number to 0
pos_counter = 0 # sets starting positive counter to 0
neu_counter = 0
neg_counter = 0

dfpos = pd.DataFrame(columns = ['date', 'title', 'link']) #initializes df where positive titles are stored
dfneu = pd.DataFrame(columns = ['date', 'title', 'link'])
dfneg = pd.DataFrame(columns = ['date', 'title', 'link'])

# for the sentiment histogram
sent_hist = []

# Separate the sentiment values into pos, neu, and neg
while i < len(df):
    sent_hist.append(df.iloc[i,5]) # added for the sentiment histogram
    if df.iloc[i,5] > 0.0:
        pos_counter += 1
        dfpos = dfpos.append(dict(zip(dfpos.columns,[df.iloc[i,1], df.iloc[i,3], df.iloc[i,4]])), ignore_index=True) #fill dfpos df
        #print(dfpos.head(), '348 Separate')
        
    elif df.iloc[i,5] == 0.0:
            neu_counter += 1
            dfneu = dfneu.append(dict(zip(dfneu.columns,[df.iloc[i,1], df.iloc[i,3], df.iloc[i,4]])), ignore_index=True)

    elif df.iloc[i,5] < 0.0:
            neg_counter += 1
            dfneg = dfneg.append(dict(zip(dfneg.columns,[df.iloc[i,1], df.iloc[i,3], df.iloc[i,4]])), ignore_index=True)
            
    i += 1
    
    #print(df.head(), '359 Separate sentiment values')
    
#### SENTIMENT HISTOGRAM
time.sleep(1)
sent_hist = np.asarray(sent_hist)
plt.figure()
#plt.hist(sent_hist, bins=20, range=[-1.0, 1.0])
plt.hist(sent_hist, bins=[-1.0,-0.95,-0.85,-0.75, -0.65, -0.55, -0.45, -0.45, -0.35, -0.25, -0.15,
                          -0.05, 0.05, 0.10, 0.15, 0.25, 0.35, 0.45, 0.55, 0.65, 0.75, 0.85, 0.95, 
                          1.0], range = [-1.0, 1.0]) 
plt.title('Histogram of Sentiment Values')
plt.xlabel('Sentiment Value')
plt.ylabel('Number of articles')
plt.grid()

fig = plt.gcf()
fig.set_size_inches(16,5) #adjusts the histogram's size
plt.show()

time.sleep(1)

print('NOTE: The 0.0 bar contains both neutral and no comment sentiments. \n')
print('The total number of articles is: ', len(df), '\n')

#### PIE CHART

# Data to plot
labels = ['Positive', 'Neutral', 'Negative']
sizes = [pos_counter, neu_counter, neg_counter] #size of each individual slice
colors = ['lightblue', 'orange', 'pink']
explode = (0.1, 0, 0)  # explode 1st slice

# Plot
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)

'''#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)'''

plt.axis('equal')

print(tickers)
print('The percent of articles with Positive, Neutral and Negative sentiment.')

fig = plt.gcf()
fig.set_size_inches(10,10) #adjusts the pie chart's size
plt.show()

time.sleep(5)

#### produces the word clouds;
print('\n*****************')
print('POSITIVE SENTIMENT: ')
print('The number of positive sentiment numbers is: ', pos_counter)
print('The percent of postive sentiment numbers is: ', pos_counter/len(df) * 100,'% \n')

time.sleep(1)
if pos_counter != 0:
    wc(remove(dfpos,remove_stopwords())) #creates the word cloud
else:
    print('There are no positive articles.')

#### Title searches on key words for postive ratings

time.sleep(1)
repeat = 'yes' #initializes repeat to 'yes'; the user can/will change this in the search_repeat() method
    
while repeat in yes_answer:
    repeat = search_repeat(dfpos) #at this point the dataframe is only the date and title

print('Moving on ...')

time.sleep(1)

print('\n*****************')
print('NEUTRAL SENTIMENT:')
print('The number of neutral sentiment numbers is: ', neu_counter)
print('The percent of neutral sentiment numbers is: ', neu_counter/len(df) * 100,'% \n')

if neu_counter != 0:
    wc(remove(dfneu,remove_stopwords())) #creates the word cloud
else:
    print('There are no neutral articles.')

#### Title searches on key words for neutral ratings
time.sleep(1)
repeat = 'yes'
while repeat in yes_answer:
    repeat = search_repeat(dfneu)

print('Moving on ...')

time.sleep(1)

print('\n*****************')
print('NEGATIVE SENTIMENT: ')
print('The number of negative sentiment numbers is: ', neg_counter)
print('The percent of negativetive sentiment numbers is: ', neg_counter/len(df) * 100,'% \n')

if neg_counter != 0:
    wc(remove(dfneg,remove_stopwords())) #creates the word cloud
else:
    print('There are no negative articles.')

#### Title searches on key words for negative ratings
time.sleep(1)
repeat = 'yes'
while repeat in yes_answer:
    repeat = search_repeat(dfneg)

print('All done ...')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\pstri\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\pstri\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\pstri\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# What is the symbol of the stock? (Please enter only one.) cost
# Do you want to remove the stopwords from the titles? [press "enter" for no]y
#
# The stopwords will be removed.
#
# ['cost']
# Date Range of the 100 most recent articles:
# Most Recent Article Date:  2021-07-31
# Oldest Article Date:  2021-06-07
# NOTE: The 0.0 bar contains both neutral and no comment sentiments.
#
# The total number of articles is:  100
#
# ['cost']
# The percent of articles with Positive, Neutral and Negative sentiment.
# *****************
# POSITIVE SENTIMENT:
# The number of positive sentiment numbers is:  47
# The percent of postive sentiment numbers is:  47.0 %
# What is the key word you want to search? [press "enter" for none] Buy
#
# 2021-07-31 12 Best Bear Market Stocks to Buy Now
# https://finance.yahoo.com/news/12-best-bear-market-stocks-145047002.html
#
# 2021-07-12 The Zacks Analyst Blog Highlights: Target, L Brands, Walmart, Costco and Best Buy
# https://finance.yahoo.com/news/zacks-analyst-blog-highlights-target-111611049.html
#
# 2021-07-09 E-Commerce Continues to Boost Retail Sales: 5 Stocks to Buy
# https://finance.yahoo.com/news/e-commerce-continues-boost-retail-120012059.html
#
# 2021-06-24 10 Best Defensive Stocks to Buy Today According to Billionaire Ken Fisher
# https://finance.yahoo.com/news/10-best-defensive-stocks-buy-135847642.html
#
# 2021-06-21 7 Fun Stocks to Buy to Introduce Your Kids to the Stock Market
# https://finance.yahoo.com/news/7-fun-stocks-buy-introduce-181202853.html
#
# 2021-06-20 The Dogecoin Bubble Will Burst: Buy These Surefire Stocks Instead
# https://www.fool.com/investing/2021/06/20/the-dogecoin-bubble-will-burst-buy-surefire-stocks/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article
#
# 2021-06-09 10 Best Stocks to Buy According to Billionaire Ray Dalio
# https://finance.yahoo.com/news/10-best-stocks-buy-according-142805082.html
#
# Do you want to do another search? [Enter either a "y" or "n."]n
# Moving on ...
#
# *****************
# NEUTRAL SENTIMENT:
# The number of neutral sentiment numbers is:  41
# The percent of neutral sentiment numbers is:  41.0 %
# What is the key word you want to search? [press "enter" for none]
#
# Moving on ...
#
# *****************
# NEGATIVE SENTIMENT:
# The number of negative sentiment numbers is:  12
# The percent of negativetive sentiment numbers is:  12.0 %
# What is the key word you want to search? [press "enter" for none]
#
# All done ...

# %%
# Data to plot
labels = ['Positive', 'Neutral', 'Negative']
sizes = [pos_counter, neu_counter, neg_counter] #size of each individual slice
colors = ['lightblue', 'orange', 'pink']
explode = (0.1, 0, 0)  # explode 1st slice

# Plot
#plt.pie(sizes, explode=explode, labels=labels, colors=colors,
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)

'''#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)'''

plt.axis('equal')
#plt.figure(figsize=(16,12))

print(tickers)
print('The percent of articles with Positive, Neutral and Negative sentiment.')

fig = plt.gcf()
fig.set_size_inches(10,10) # or (4,4) or (5,5) or whatever
plt.show()
# Out:
# ['arkg']
# The percent of articles with Positive, Neutral and Negative sentiment.

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
import re

# %%
# This also scrapes the url links from the web page and makes it available.

symbol = input('What is the symbol of the stock? (Please enter only one.)')

#### SCRAPES FINVIZ

finviz_url = 'https://www.finviz.com/quote.ashx?t='
#tickers = ['NVDA', 'SLV', 'MU']
tickers = [symbol]

news_tables = {}

for ticker in tickers:
    url = finviz_url + ticker
    
    req = Request(url = url, headers = {'user-agent': 'my-app'})
    response = urlopen(req)
    
    html = BeautifulSoup(response, 'html')
    news_table = html.find(id = 'news-table') # in html : id = "news-table"; line # 551
    news_tables[ticker] = news_table

print('\n#######\n')
#print(news_table)
    
parsed_data = []

for ticker, news_table in news_tables.items():
    
    print('ticker: ', ticker)

    for row in news_table.findAll('tr'):

        
        title = row.a.get_text() #captures the title
        print('title = ', title)
        
        link = row.a.get('href') #captures the link
        print('link =', link)
        
        date_data = row.td.text.split(' ')
        
        if len(date_data) == 1: # if there is both a date and time it parses them into two columns
            time = date_data[0]
        else: 
            date = date_data[0] 
            time = date_data[1]
        parsed_data.append([ticker, date, time, title, link])
        
df = pd.DataFrame(parsed_data, columns = ['ticker', 'date', 'time', 'title', 'link'])

print('\n dataframe: \n', df)
# Out:
# What is the symbol of the stock? (Please enter only one.)intc
#
# #######
#
# ticker:  intc
# title =  Intels New CEO Vows to Move Faster. But Hold Off on the Stock for Now.
# link = https://www.barrons.com/articles/intel-new-ceo-wait-to-buy-stock-51627685968?siteid=yhoof2
# title =  Here's Why AMD's Acquisition of Xilinx Is Such a Great Deal
# link = https://www.fool.com/investing/2021/07/30/heres-why-amds-acquisition-of-xilinx-is-such-a-gre/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article
# title =  Bull of the Day: Advanced Micro Devices (AMD)
# link = https://finance.yahoo.com/news/bull-day-advanced-micro-devices-092009068.html
# title =  Fluid Foundations: How Brian Faist's Career Helping the Environment Started With a Prank Gone Horribly Wrong
# link = https://finance.yahoo.com/news/fluid-foundations-brian-faists-career-190106773.html
# title =  AMD CEO: 'Demand for computing is exploding'
# link = https://finance.yahoo.com/news/amd-ceo-demand-for-computing-is-exploding-173949300.html
# title =  The Chip-Crunch Recovery Will Be Rocky, as Apple Can Attest
# link = https://finance.yahoo.com/news/chip-shortage-recovery-rocky-apple-235846980.html
# title =  2 Bargain Stocks You Can Buy Today
# link = https://www.fool.com/investing/2021/07/29/2-bargain-stocks-you-can-buy-today/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article
# title =  Dow Jones Today Leads After Mixed Jobs/GDP Data; Steel, Chips, Vaccine, Infrastructure Stocks Rise; Facebook, PayPal Dive On Earnings
# link = https://www.investors.com/market-trend/stock-market-today/dow-jones-today-gains-ahead-of-jobs-gdp-data-steel-chips-vaccine-infrastructure-stocks-rising-facebook-paypal-dive-on-earnings/?src=A00220
# title =  Is Intel Stock Finally Worth Buying?
# link = https://www.fool.com/investing/2021/07/29/is-intel-stock-finally-worth-buying/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article
# title =  Media Alert: Intel at Black Hat 2021 and DEF CON 29
# link = https://finance.yahoo.com/news/media-alert-intel-black-hat-220000871.html
# title =  AMD Stock Closed at a Record. Heres What Wall Street Is Saying.
# link = https://www.barrons.com/articles/amd-stock-record-high-earnings-51627504349?siteid=yhoof2
# title =  Qualcomm Gives Upbeat Forecast, Lifted by 5G Smartphone Demand
# link = https://finance.yahoo.com/news/qualcomm-gives-upbeat-forecast-lifted-200801266.html
# title =  AMDs stock surges to record high while chip maker takes more market share from Intel
# link = https://www.marketwatch.com/story/amd-stock-flirts-with-record-highs-while-chip-maker-takes-more-market-share-from-intel-11627487890?siteid=yhoof2
# title =  What I Liked About AMD's Earnings
# link = https://www.fool.com/investing/2021/07/28/what-i-liked-about-amds-earnings/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article
# title =  Intel vs. AMD: Which Semiconductor Stock Is a Better Pick?
# link = https://finance.yahoo.com/news/intel-vs-amd-semiconductor-stock-143733463.html
# title =  Stock Market News for Jul 28, 2021
# link = https://finance.yahoo.com/news/stock-market-news-jul-28-134501169.html
# title =  Intel CEO: We have 100 companies that want us to make their chips
# link = https://finance.yahoo.com/news/intel-ceo-we-have-100-companies-that-want-us-to-make-their-chips-120023723.html
# title =  Hey Intel, AMDs CEO is also ready to fight for every socket, while producing strong growth
# link = https://www.marketwatch.com/story/amd-stock-rises-as-data-center-gaming-segment-sales-nearly-triple-11627417746?siteid=yhoof2
# title =  AMD Gives Optimistic Revenue Outlook on Strong Demand
# link = https://finance.yahoo.com/news/amd-gives-optimistic-outlook-beats-203159748.html
# title =  Dow Jones Falls Below 35,000 on Boeing and Tech Stock Sell-Offs, Delta Variant Worries
# link = https://www.fool.com/investing/2021/07/27/dow-jones-falls-below-35000-on-boeing-and-tech-sto/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article
# title =  Intel changed the name of its chips, but analysts say the story hasnt changed
# link = https://www.marketwatch.com/story/intel-changed-the-name-of-its-chips-but-analysts-say-the-story-hasnt-changed-11627413565?siteid=yhoof2
# title =  Intel CEO on the chip industry: You can't be a little player
# link = https://finance.yahoo.com/news/intel-ceo-on-the-chip-industry-you-cant-be-a-little-player-175853537.html
# title =  Qualcomm (QCOM) Option Traders Bullish Into Earnings
# link = https://www.investopedia.com/qualcomm-qcom-option-traders-bullish-into-earnings-5194371?utm_campaign=quote-yahoo&utm_source=yahoo&utm_medium=referral
# title =  We will be a leader in chips again: Intel CEO
# link = https://finance.yahoo.com/video/leader-chips-again-intel-ceo-165437529.html
# title =  US STOCKS-Nasdaq set for worst day in 2 months before big tech earnings
# link = https://finance.yahoo.com/news/us-stocks-nasdaq-set-worst-163339141.html
# title =  Heres what to expect from Apples Q3 earnings
# link = https://finance.yahoo.com/video/expect-apple-q3-earnings-155943654.html
# title =  Intel to make Qualcomm chips
# link = https://finance.yahoo.com/video/intel-qualcomm-chips-153936391.html
# title =  3 Stocks to Make the Most of the Bitcoin Rebound
# link = https://finance.yahoo.com/news/3-stocks-most-bitcoin-rebound-112711989.html
# title =  Tesla, Apple, AMD, General Electric and Lucid - 5 Things You Must Know Tuesday
# link = https://www.thestreet.com/markets/5-things-you-must-know-before-market-opens-tuesday-072721?puc=yahoo&cm_ven=YAHOO
# title =  Intel Pledges to Retake Innovation Crown, Changes Yardstick
# link = https://finance.yahoo.com/news/intel-pledges-retake-innovation-crown-210000696.html
# title =  Intel stock dips as new chip designation, production schedule revealed
# link = https://www.marketwatch.com/story/intel-stock-dips-as-new-chip-designation-production-schedule-revealed-11627338595?siteid=yhoof2
# title =  UPDATE 1-Intel to build Qualcomm chips, aims to catch foundry rivals by 2025
# link = https://finance.yahoo.com/news/1-intel-build-qualcomm-chips-215606020.html
# title =  EXPLAINER-Intel banks on 3D chip technology to win over new customers
# link = https://finance.yahoo.com/news/explainer-intel-banks-3d-chip-214438067.html
# title =  Intel to build Qualcomm chips, aims to catch foundry rivals by 2025
# link = https://finance.yahoo.com/news/intel-build-qualcomm-chips-aims-210415654.html
# title =  Intel Lays Out Chip Manufacturing Plans Through 2025
# link = https://www.barrons.com/articles/intel-lays-out-chip-manufacturing-plans-through-2025-51627332889?siteid=yhoof2
# title =  Intel Accelerates Process and Packaging Innovations
# link = https://finance.yahoo.com/news/intel-accelerates-process-packaging-innovations-210000002.html
# title =  Dow Jones Gains, Nasdaq Closes Positive; Tesla Earnings Beat As Bitcoin Soars; IPO Passes Buy
# link = https://www.investors.com/market-trend/stock-market-today/dow-jones-gains-tesla-stock-surges-ahead-of-earnings-bitcoin-soars-ipo-stock-passes-entry/?src=A00220
# title =  This could be the peak of the tech boom  Heres what to look for
# link = https://www.marketwatch.com/story/this-could-be-the-peak-of-the-tech-boom-heres-what-to-look-for-11627328501?siteid=yhoof2
# title =  Dow Jones Targets New High As These Stocks Lead; Tesla, Apple, Microsoft Earnings On Tap
# link = https://www.investors.com/market-trend/stock-market-today/dow-jones-targets-new-high-tesla-apple-microsoft-earnings-on-tap/?src=A00220
# title =  Why Nvidia Stock Just Dropped
# link = https://www.fool.com/investing/2021/07/26/why-nvidia-stock-just-dropped/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article
# title =  Can Intels Strong Earnings Offset Supply Constraints?
# link = https://finance.yahoo.com/news/intel-strong-earnings-offset-supply-150930126.html
# title =  What AMD Investors Should Watch for This Week After Intel's Earnings Report
# link = https://www.fool.com/investing/2021/07/26/what-amd-investors-should-watch-for-this-week-afte/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article
# title =  Is This the Best Semiconductor Stock Right Now?
# link = https://www.fool.com/investing/2021/07/26/is-this-the-best-semiconductor-stock-right-now/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article
# title =  3 Reasons I'm Betting on Intel's Comeback
# link = https://www.fool.com/investing/2021/07/26/reasons-betting-on-intel-comeback-tsmc-amd/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article
# title =  Is the Chip Shortage Over? Not So Fast
# link = https://www.fool.com/investing/2021/07/26/is-the-chip-shortage-over-not-so-fast/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article
# title =  TSMC Mulls German, Japan Plants to Diversify Supply Chain
# link = https://finance.yahoo.com/news/tsmc-mulls-german-japan-plants-034136138.html
# title =  3 Companies Moving Forward With Robotaxis as Tesla Delays
# link = https://www.fool.com/investing/2021/07/24/3-companies-moving-forward-with-robotaxis-as-tesla/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article
# title =  4 Things You Might Have Gotten Wrong About Intel
# link = https://www.fool.com/investing/2021/07/24/4-things-you-might-have-gotten-wrong-about-intel/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article
# title =  Question not whether AMD can take market share from Intel, but just how much
# link = https://www.marketwatch.com/story/question-not-whether-amd-can-take-market-share-from-intel-but-just-how-much-11627077401?siteid=yhoof2
# title =  Intel Reported Strong Earnings. But Its Margins Are Suffering.
# link = https://www.barrons.com/articles/intel-reported-strong-earnings-but-its-margins-are-suffering-51627075005?siteid=yhoof2
# title =  Why Intel Stock Plunged Today
# link = https://www.fool.com/investing/2021/07/23/why-intel-stock-plunged-today/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article
# title =  US STOCKS-Wall Street surges to all-time closing high on earnings, economic revival
# link = https://finance.yahoo.com/news/us-stocks-wall-street-surges-202409605.html
# title =  Intel Stock Drops As Chipmaker's Outlook Signals Lower Profits
# link = https://www.investors.com/news/technology/intel-stock-chipmaker-handily-beats-sales-profit-goals/?src=A00220
# title =  Dow Jones Up 195 Points, in Record Territory Despite Intel Worries
# link = https://www.fool.com/investing/2021/07/23/dow-jones-up-195-points-in-record-territory-despit/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article
# title =  US STOCKS-Wall Street extends rally, S&P, Nasdaq on course for record closing highs
# link = https://finance.yahoo.com/news/us-stocks-wall-street-extends-181342482.html
# title =  Intel's Q2 Results Show It Is Not Losing Focus
# link = https://finance.yahoo.com/news/intels-q2-results-show-not-180828631.html
# title =  UPDATE 1-Intel, TI split leaves chip outlook in doubt
# link = https://finance.yahoo.com/news/1-intel-ti-split-leaves-175019658.html
# title =  Dow Jones Extends Weekly Gain, Nasdaq Leads Upside; Twitter Stock, Snap Rise On Earnings
# link = https://www.investors.com/market-trend/stock-market-today/dow-jones-extends-weekly-gain-nasdaq-leads-upside-twitter-stock-snap-rise-on-earnings/?src=A00220
# title =  Dow Jones Rallies As Snap, Twitter Jump On Earnings Beats; Chinese Stocks Plunge On Crackdown
# link = https://www.investors.com/market-trend/stock-market-today/dow-jones-rallies-as-snap-twitter-jump-on-earnings-chinese-stocks-plunge-on-crackdown/?src=A00220
# title =  US STOCKS-S&P 500, Nasdaq hit record highs on megacaps, earnings strength
# link = https://finance.yahoo.com/news/us-stocks-p-500-nasdaq-162537960.html
# title =  Intel stock drops as signs of continued AMD share gains eclipse earnings beat
# link = https://www.marketwatch.com/story/intel-stock-drops-as-signs-of-continued-amd-share-gains-eclipse-earnings-beat-11627057291?siteid=yhoof2
# title =  Why Intel's M&A strategy has this analyst 'a little worried'
# link = https://finance.yahoo.com/video/why-intels-m-strategy-analyst-160137637.html
# title =  Intel Server-Chip Woes Drag on Sales Forecast; Shares Slump
# link = https://finance.yahoo.com/news/intel-server-chip-woes-drag-001402503.html
# title =  CORRECTED-US STOCKS-Wall St rises on strong earnings, chipmakers fall after Intel outlook
# link = https://finance.yahoo.com/news/us-stocks-wall-st-rises-142859491.html
# title =  Intel Q2 Earnings Put These ETFs in Focus
# link = https://finance.yahoo.com/news/intel-q2-earnings-put-etfs-140502251.html
# title =  Dow Jones Today, Stocks Surge As Snap, Twitter, Skechers Ace Breakouts; China Stocks Tumble
# link = https://www.investors.com/market-trend/stock-market-today/dow-jones-today-futures-rise-as-snap-twitter-skechers-eye-breakouts-social-media-stocks-rally/?src=A00220
# title =  Breaking down the key takeaways from Thursdays earnings reports
# link = https://finance.yahoo.com/video/breaking-down-key-takeaways-thursday-133759360.html
# title =  Intel Slumps to a New Low From Their Move Down Started in April
# link = https://realmoney.thestreet.com/investing/intel-slumps-to-a-new-low-from-their-move-down-started-in-april-15721109?puc=yahoo&cm_ven=YAHOO
# title =  US STOCKS-Wall St set to open higher on megacap tech boost, strong earnings
# link = https://finance.yahoo.com/news/us-stocks-wall-st-set-125621548.html
# title =  Dow Jones Futures: Apple, Microsoft Lead Market Rally; Snap, Twitter Surge On Earnings, Chinese Stocks Hit
# link = https://www.investors.com/market-trend/stock-market-today/dow-jones-futures-apple-microsoft-lead-market-rally-snap-twitter-surge-on-earnings/?src=A00220
# title =  Intel (INTC) Q2 Earnings & Revenues Top Estimates, '21 View Up
# link = https://finance.yahoo.com/news/intel-intc-q2-earnings-revenues-120412352.html
# title =  Chip Stocks Cant Win Right Now. Investors Can.
# link = https://www.barrons.com/articles/things-to-know-today-51627034645?siteid=yhoof2
# title =  Dwelling Deeper In Intel's Q2 Earnings Beat, Optimistic Q3 Estimates
# link = https://finance.yahoo.com/news/dwelling-deeper-intels-q2-earnings-111237911.html
# title =  Intel, TI split leaves chip outlook in doubt
# link = https://finance.yahoo.com/news/intel-ti-split-leaves-chip-094834619.html
# title =  Intel, TI split leaves chip outlook in doubt
# link = https://finance.yahoo.com/news/intel-ti-split-leaves-chip-094429196.html
# title =  Twitter, Snap, Schlumberger Rise Premarket; Intel Falls
# link = https://finance.yahoo.com/news/twitter-snap-schlumberger-rise-premarket-080408235.html
# title =  Intel Shares Slump as Muted 2021 Forecast, Margins Cloud Solid Earnings
# link = https://www.thestreet.com/investing/intel-shares-slump-as-muted-2021-forecast-clouds-solid-earnings?puc=yahoo&cm_ven=YAHOO
# title =  Intel (INTC) Q2 2021 Earnings Call Transcript
# link = https://www.fool.com/earnings/call-transcripts/2021/07/23/intel-intc-q2-2021-earnings-call-transcript/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article
# title =  Intel Falls As Forecast Underwhelms, Chip Shortage Could Prolong
# link = https://finance.yahoo.com/news/intel-falls-forecast-underwhelms-chip-054636960.html
# title =  Snap, Twitter, Intel, Honeywell, American Express - 5 Things You Must Know Friday
# link = https://www.thestreet.com/markets/5-things-you-must-know-before-market-opens-friday-072321?puc=yahoo&cm_ven=YAHOO
# title =  Intel appears to be feeling the competitive heat from AMD
# link = https://www.marketwatch.com/story/intel-appears-to-be-feeling-the-competitive-heat-from-amd-11627004561?siteid=yhoof2
# title =  Intel CEO Says Global Chip Shortage Will Get Worse Before It Gets Better
# link = https://www.barrons.com/articles/intel-earnings-global-chip-shortage-51626998346?siteid=yhoof2
# title =  Intel says chip shortage could drag into 2023 as outlook barely clears Street view
# link = https://www.marketwatch.com/story/intel-stock-ticks-lower-as-outlook-barely-clears-wall-street-expectations-following-beat-11626985199?siteid=yhoof2
# title =  Intel Beats, Twitter & Snap Crush Estimates
# link = https://finance.yahoo.com/news/intel-beats-twitter-snap-crush-214309358.html
# title =  Intel stocks rises after positive Q2 earnings
# link = https://finance.yahoo.com/video/intel-stocks-rises-positive-q2-212759733.html
# title =  Intel (INTC) Tops Q2 Earnings and Revenue Estimates
# link = https://finance.yahoo.com/news/intel-intc-tops-q2-earnings-212009632.html
# title =  Intels Sales Forecast Falls Short as Data Center Unit Sags
# link = https://finance.yahoo.com/news/intel-sales-forecast-falls-short-202829834.html
# title =  Intel raises full-year sales forecast, but second-half demand worries send shares down
# link = https://finance.yahoo.com/news/intel-forecasts-current-quarter-revenue-201350914.html
# title =  Chipmaker Intel raises annual revenue forecast
# link = https://finance.yahoo.com/news/chipmaker-intel-raises-annual-revenue-201038023.html
# title =  UPDATE 4-Intel raises full-year sales forecast, but second-half demand worries send shares down
# link = https://finance.yahoo.com/news/1-chipmaker-intel-raises-annual-200812550.html
# title =  Intel Arizona RISE Report: Our Commitment to Our Community and Corporate Responsibility
# link = https://finance.yahoo.com/news/intel-arizona-rise-report-commitment-184607598.html
# title =  Intel Falls After Second-Quarter Earnings Beat, Tepid Guidance
# link = https://www.thestreet.com/investing/intel-falls-after-second-quarter-earnings-beat-tepid-guidance?puc=yahoo&cm_ven=YAHOO
# title =  Dow Jones Falls On Surprise Jump In Jobless Claims; Snap, Twitter Set To Report Earnings
# link = https://www.investors.com/market-trend/stock-market-today/dow-jones-falls-on-surprise-jump-in-jobless-claims-snap-twitter-earnings-due/?src=A00220
# title =  Texas Instruments tops estimates, but chip demand concerns linger
# link = https://finance.yahoo.com/video/texas-instruments-tops-estimates-chip-143641374.html
# title =  Low Expectations Ahead of Intel Report
# link = https://finance.yahoo.com/news/low-expectations-ahead-intel-report-131624574.html
# title =  Warning From Major Chipmaker Adds to Worries Industry Will Produce More Than Demand
# link = https://finance.yahoo.com/news/one-world-largest-chipmakers-worries-033935633.html
# title =  Texas Instruments Forecast Stokes Concern Over Chip Demand
# link = https://finance.yahoo.com/news/texas-instruments-sales-forecast-stirs-202527038.html
# title =  Intel Reports Earnings Today. Expectations Are High.
# link = https://www.barrons.com/articles/intel-earnings-51626886116?siteid=yhoof2
# title =  Chip Shortages, Jobless Claims, ECB, Musk Lifts Bitcoin  - What's Moving Markets
# link = https://finance.yahoo.com/news/chip-shortages-jobless-claims-ecb-063658686.html
# title =  Intel's foundry ambitions could be slowed by lack of deal targets
# link = https://finance.yahoo.com/news/intels-foundry-ambitions-could-slowed-213354344.html
#
#  dataframe:
#     ticker       date       time  \
# 0    intc  Jul-30-21  07:04PM
# 1    intc  Jul-30-21  12:30PM
# 2    intc  Jul-30-21  05:20AM
# 3    intc  Jul-29-21  03:01PM
# 4    intc  Jul-29-21  01:39PM
# ..    ...        ...        ...
# 95   intc  Jul-22-21  06:52AM
# 96   intc  Jul-22-21  06:37AM
# 97   intc  Jul-22-21  04:00AM
# 98   intc  Jul-22-21  02:36AM
# 99   intc  Jul-21-21  05:33PM
#
#                                                 title  \
# 0   Intels New CEO Vows to Move Faster. But Hold O...
# 1   Here's Why AMD's Acquisition of Xilinx Is Such...
# 2       Bull of the Day: Advanced Micro Devices (AMD)
# 3   Fluid Foundations: How Brian Faist's Career He...
# 4        AMD CEO: 'Demand for computing is exploding'
# ..                                                ...
# 95  Warning From Major Chipmaker Adds to Worries I...
# 96  Texas Instruments Forecast Stokes Concern Over...
# 97  Intel Reports Earnings Today. Expectations Are...
# 98  Chip Shortages, Jobless Claims, ECB, Musk Lift...
# 99  Intel's foundry ambitions could be slowed by l...
#
#                                                  link
# 0   https://www.barrons.com/articles/intel-new-ceo...
# 1   https://www.fool.com/investing/2021/07/30/here...
# 2   https://finance.yahoo.com/news/bull-day-advanc...
# 3   https://finance.yahoo.com/news/fluid-foundatio...
# 4   https://finance.yahoo.com/news/amd-ceo-demand-...
# ..                                                ...
# 95  https://finance.yahoo.com/news/one-world-large...
# 96  https://finance.yahoo.com/news/texas-instrumen...
# 97  https://www.barrons.com/articles/intel-earning...
# 98  https://finance.yahoo.com/news/chip-shortages-...
# 99  https://finance.yahoo.com/news/intels-foundry-...
#
# [100 rows x 5 columns]

# %%
display(df['link'])
# Out:
# 0     https://www.barrons.com/articles/intel-new-ceo...
# 1     https://www.fool.com/investing/2021/07/30/here...
# 2     https://finance.yahoo.com/news/bull-day-advanc...
# 3     https://finance.yahoo.com/news/fluid-foundatio...
# 4     https://finance.yahoo.com/news/amd-ceo-demand-...
#                             ...
# 95    https://finance.yahoo.com/news/one-world-large...
# 96    https://finance.yahoo.com/news/texas-instrumen...
# 97    https://www.barrons.com/articles/intel-earning...
# 98    https://finance.yahoo.com/news/chip-shortages-...
# 99    https://finance.yahoo.com/news/intels-foundry-...
# Name: link, Length: 100, dtype: object

# %%
# how to write a field without using a print statement - print statements truncate the record when the print it out.
import sys

i = 0
    
while i < len(df):
    link = df.loc[i,'link']
    title = df.loc[i,'title']
    print()
    sys.stdout.write(title)
    print()
    sys.stdout.write(link)
    print()
    
    i += 1
# Out:
# Intels New CEO Vows to Move Faster. But Hold Off on the Stock for Now.
# https://www.barrons.com/articles/intel-new-ceo-wait-to-buy-stock-51627685968?siteid=yhoof2
#
# Here's Why AMD's Acquisition of Xilinx Is Such a Great Deal
# https://www.fool.com/investing/2021/07/30/heres-why-amds-acquisition-of-xilinx-is-such-a-gre/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article
#
# Bull of the Day: Advanced Micro Devices (AMD)
# https://finance.yahoo.com/news/bull-day-advanced-micro-devices-092009068.html
#
# Fluid Foundations: How Brian Faist's Career Helping the Environment Started With a Prank Gone Horribly Wrong
# https://finance.yahoo.com/news/fluid-foundations-brian-faists-career-190106773.html
#
# AMD CEO: 'Demand for computing is exploding'
# https://finance.yahoo.com/news/amd-ceo-demand-for-computing-is-exploding-173949300.html
#
# The Chip-Crunch Recovery Will Be Rocky, as Apple Can Attest
# https://finance.yahoo.com/news/chip-shortage-recovery-rocky-apple-235846980.html
#
# 2 Bargain Stocks You Can Buy Today
# https://www.fool.com/investing/2021/07/29/2-bargain-stocks-you-can-buy-today/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article
#
# Dow Jones Today Leads After Mixed Jobs/GDP Data; Steel, Chips, Vaccine, Infrastructure Stocks Rise; Facebook, PayPal Dive On Earnings
# https://www.investors.com/market-trend/stock-market-today/dow-jones-today-gains-ahead-of-jobs-gdp-data-steel-chips-vaccine-infrastructure-stocks-rising-facebook-paypal-dive-on-earnings/?src=A00220
#
# Is Intel Stock Finally Worth Buying?
# https://www.fool.com/investing/2021/07/29/is-intel-stock-finally-worth-buying/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article
#
# Media Alert: Intel at Black Hat 2021 and DEF CON 29
# https://finance.yahoo.com/news/media-alert-intel-black-hat-220000871.html
#
# AMD Stock Closed at a Record. Heres What Wall Street Is Saying.
# https://www.barrons.com/articles/amd-stock-record-high-earnings-51627504349?siteid=yhoof2
#
# Qualcomm Gives Upbeat Forecast, Lifted by 5G Smartphone Demand
# https://finance.yahoo.com/news/qualcomm-gives-upbeat-forecast-lifted-200801266.html
#
# AMDs stock surges to record high while chip maker takes more market share from Intel
# https://www.marketwatch.com/story/amd-stock-flirts-with-record-highs-while-chip-maker-takes-more-market-share-from-intel-11627487890?siteid=yhoof2
#
# What I Liked About AMD's Earnings
# https://www.fool.com/investing/2021/07/28/what-i-liked-about-amds-earnings/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article
#
# Intel vs. AMD: Which Semiconductor Stock Is a Better Pick?
# https://finance.yahoo.com/news/intel-vs-amd-semiconductor-stock-143733463.html
#
# Stock Market News for Jul 28, 2021
# https://finance.yahoo.com/news/stock-market-news-jul-28-134501169.html
#
# Intel CEO: We have 100 companies that want us to make their chips
# https://finance.yahoo.com/news/intel-ceo-we-have-100-companies-that-want-us-to-make-their-chips-120023723.html
#
# Hey Intel, AMDs CEO is also ready to fight for every socket, while producing strong growth
# https://www.marketwatch.com/story/amd-stock-rises-as-data-center-gaming-segment-sales-nearly-triple-11627417746?siteid=yhoof2
#
# AMD Gives Optimistic Revenue Outlook on Strong Demand
# https://finance.yahoo.com/news/amd-gives-optimistic-outlook-beats-203159748.html
#
# Dow Jones Falls Below 35,000 on Boeing and Tech Stock Sell-Offs, Delta Variant Worries
# https://www.fool.com/investing/2021/07/27/dow-jones-falls-below-35000-on-boeing-and-tech-sto/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article
#
# Intel changed the name of its chips, but analysts say the story hasnt changed
# https://www.marketwatch.com/story/intel-changed-the-name-of-its-chips-but-analysts-say-the-story-hasnt-changed-11627413565?siteid=yhoof2
#
# Intel CEO on the chip industry: You can't be a little player
# https://finance.yahoo.com/news/intel-ceo-on-the-chip-industry-you-cant-be-a-little-player-175853537.html
#
# Qualcomm (QCOM) Option Traders Bullish Into Earnings
# https://www.investopedia.com/qualcomm-qcom-option-traders-bullish-into-earnings-5194371?utm_campaign=quote-yahoo&utm_source=yahoo&utm_medium=referral
#
# We will be a leader in chips again: Intel CEO
# https://finance.yahoo.com/video/leader-chips-again-intel-ceo-165437529.html
#
# US STOCKS-Nasdaq set for worst day in 2 months before big tech earnings
# https://finance.yahoo.com/news/us-stocks-nasdaq-set-worst-163339141.html
#
# Heres what to expect from Apples Q3 earnings
# https://finance.yahoo.com/video/expect-apple-q3-earnings-155943654.html
#
# Intel to make Qualcomm chips
# https://finance.yahoo.com/video/intel-qualcomm-chips-153936391.html
#
# 3 Stocks to Make the Most of the Bitcoin Rebound
# https://finance.yahoo.com/news/3-stocks-most-bitcoin-rebound-112711989.html
#
# Tesla, Apple, AMD, General Electric and Lucid - 5 Things You Must Know Tuesday
# https://www.thestreet.com/markets/5-things-you-must-know-before-market-opens-tuesday-072721?puc=yahoo&cm_ven=YAHOO
#
# Intel Pledges to Retake Innovation Crown, Changes Yardstick
# https://finance.yahoo.com/news/intel-pledges-retake-innovation-crown-210000696.html
#
# Intel stock dips as new chip designation, production schedule revealed
# https://www.marketwatch.com/story/intel-stock-dips-as-new-chip-designation-production-schedule-revealed-11627338595?siteid=yhoof2
#
# UPDATE 1-Intel to build Qualcomm chips, aims to catch foundry rivals by 2025
# https://finance.yahoo.com/news/1-intel-build-qualcomm-chips-215606020.html
#
# EXPLAINER-Intel banks on 3D chip technology to win over new customers
# https://finance.yahoo.com/news/explainer-intel-banks-3d-chip-214438067.html
#
# Intel to build Qualcomm chips, aims to catch foundry rivals by 2025
# https://finance.yahoo.com/news/intel-build-qualcomm-chips-aims-210415654.html
#
# Intel Lays Out Chip Manufacturing Plans Through 2025
# https://www.barrons.com/articles/intel-lays-out-chip-manufacturing-plans-through-2025-51627332889?siteid=yhoof2
#
# Intel Accelerates Process and Packaging Innovations
# https://finance.yahoo.com/news/intel-accelerates-process-packaging-innovations-210000002.html
#
# Dow Jones Gains, Nasdaq Closes Positive; Tesla Earnings Beat As Bitcoin Soars; IPO Passes Buy
# https://www.investors.com/market-trend/stock-market-today/dow-jones-gains-tesla-stock-surges-ahead-of-earnings-bitcoin-soars-ipo-stock-passes-entry/?src=A00220
#
# This could be the peak of the tech boom  Heres what to look for
# https://www.marketwatch.com/story/this-could-be-the-peak-of-the-tech-boom-heres-what-to-look-for-11627328501?siteid=yhoof2
#
# Dow Jones Targets New High As These Stocks Lead; Tesla, Apple, Microsoft Earnings On Tap
# https://www.investors.com/market-trend/stock-market-today/dow-jones-targets-new-high-tesla-apple-microsoft-earnings-on-tap/?src=A00220
#
# Why Nvidia Stock Just Dropped
# https://www.fool.com/investing/2021/07/26/why-nvidia-stock-just-dropped/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article
#
# Can Intels Strong Earnings Offset Supply Constraints?
# https://finance.yahoo.com/news/intel-strong-earnings-offset-supply-150930126.html
#
# What AMD Investors Should Watch for This Week After Intel's Earnings Report
# https://www.fool.com/investing/2021/07/26/what-amd-investors-should-watch-for-this-week-afte/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article
#
# Is This the Best Semiconductor Stock Right Now?
# https://www.fool.com/investing/2021/07/26/is-this-the-best-semiconductor-stock-right-now/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article
#
# 3 Reasons I'm Betting on Intel's Comeback
# https://www.fool.com/investing/2021/07/26/reasons-betting-on-intel-comeback-tsmc-amd/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article
#
# Is the Chip Shortage Over? Not So Fast
# https://www.fool.com/investing/2021/07/26/is-the-chip-shortage-over-not-so-fast/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article
#
# TSMC Mulls German, Japan Plants to Diversify Supply Chain
# https://finance.yahoo.com/news/tsmc-mulls-german-japan-plants-034136138.html
#
# 3 Companies Moving Forward With Robotaxis as Tesla Delays
# https://www.fool.com/investing/2021/07/24/3-companies-moving-forward-with-robotaxis-as-tesla/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article
#
# 4 Things You Might Have Gotten Wrong About Intel
# https://www.fool.com/investing/2021/07/24/4-things-you-might-have-gotten-wrong-about-intel/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article
#
# Question not whether AMD can take market share from Intel, but just how much
# https://www.marketwatch.com/story/question-not-whether-amd-can-take-market-share-from-intel-but-just-how-much-11627077401?siteid=yhoof2
#
# Intel Reported Strong Earnings. But Its Margins Are Suffering.
# https://www.barrons.com/articles/intel-reported-strong-earnings-but-its-margins-are-suffering-51627075005?siteid=yhoof2
#
# Why Intel Stock Plunged Today
# https://www.fool.com/investing/2021/07/23/why-intel-stock-plunged-today/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article
#
# US STOCKS-Wall Street surges to all-time closing high on earnings, economic revival
# https://finance.yahoo.com/news/us-stocks-wall-street-surges-202409605.html
#
# Intel Stock Drops As Chipmaker's Outlook Signals Lower Profits
# https://www.investors.com/news/technology/intel-stock-chipmaker-handily-beats-sales-profit-goals/?src=A00220
#
# Dow Jones Up 195 Points, in Record Territory Despite Intel Worries
# https://www.fool.com/investing/2021/07/23/dow-jones-up-195-points-in-record-territory-despit/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article
#
# US STOCKS-Wall Street extends rally, S&P, Nasdaq on course for record closing highs
# https://finance.yahoo.com/news/us-stocks-wall-street-extends-181342482.html
#
# Intel's Q2 Results Show It Is Not Losing Focus
# https://finance.yahoo.com/news/intels-q2-results-show-not-180828631.html
#
# UPDATE 1-Intel, TI split leaves chip outlook in doubt
# https://finance.yahoo.com/news/1-intel-ti-split-leaves-175019658.html
#
# Dow Jones Extends Weekly Gain, Nasdaq Leads Upside; Twitter Stock, Snap Rise On Earnings
# https://www.investors.com/market-trend/stock-market-today/dow-jones-extends-weekly-gain-nasdaq-leads-upside-twitter-stock-snap-rise-on-earnings/?src=A00220
#
# Dow Jones Rallies As Snap, Twitter Jump On Earnings Beats; Chinese Stocks Plunge On Crackdown
# https://www.investors.com/market-trend/stock-market-today/dow-jones-rallies-as-snap-twitter-jump-on-earnings-chinese-stocks-plunge-on-crackdown/?src=A00220
#
# US STOCKS-S&P 500, Nasdaq hit record highs on megacaps, earnings strength
# https://finance.yahoo.com/news/us-stocks-p-500-nasdaq-162537960.html
#
# Intel stock drops as signs of continued AMD share gains eclipse earnings beat
# https://www.marketwatch.com/story/intel-stock-drops-as-signs-of-continued-amd-share-gains-eclipse-earnings-beat-11627057291?siteid=yhoof2
#
# Why Intel's M&A strategy has this analyst 'a little worried'
# https://finance.yahoo.com/video/why-intels-m-strategy-analyst-160137637.html
#
# Intel Server-Chip Woes Drag on Sales Forecast; Shares Slump
# https://finance.yahoo.com/news/intel-server-chip-woes-drag-001402503.html
#
# CORRECTED-US STOCKS-Wall St rises on strong earnings, chipmakers fall after Intel outlook
# https://finance.yahoo.com/news/us-stocks-wall-st-rises-142859491.html
#
# Intel Q2 Earnings Put These ETFs in Focus
# https://finance.yahoo.com/news/intel-q2-earnings-put-etfs-140502251.html
#
# Dow Jones Today, Stocks Surge As Snap, Twitter, Skechers Ace Breakouts; China Stocks Tumble
# https://www.investors.com/market-trend/stock-market-today/dow-jones-today-futures-rise-as-snap-twitter-skechers-eye-breakouts-social-media-stocks-rally/?src=A00220
#
# Breaking down the key takeaways from Thursdays earnings reports
# https://finance.yahoo.com/video/breaking-down-key-takeaways-thursday-133759360.html
#
# Intel Slumps to a New Low From Their Move Down Started in April
# https://realmoney.thestreet.com/investing/intel-slumps-to-a-new-low-from-their-move-down-started-in-april-15721109?puc=yahoo&cm_ven=YAHOO
#
# US STOCKS-Wall St set to open higher on megacap tech boost, strong earnings
# https://finance.yahoo.com/news/us-stocks-wall-st-set-125621548.html
#
# Dow Jones Futures: Apple, Microsoft Lead Market Rally; Snap, Twitter Surge On Earnings, Chinese Stocks Hit
# https://www.investors.com/market-trend/stock-market-today/dow-jones-futures-apple-microsoft-lead-market-rally-snap-twitter-surge-on-earnings/?src=A00220
#
# Intel (INTC) Q2 Earnings & Revenues Top Estimates, '21 View Up
# https://finance.yahoo.com/news/intel-intc-q2-earnings-revenues-120412352.html
#
# Chip Stocks Cant Win Right Now. Investors Can.
# https://www.barrons.com/articles/things-to-know-today-51627034645?siteid=yhoof2
#
# Dwelling Deeper In Intel's Q2 Earnings Beat, Optimistic Q3 Estimates
# https://finance.yahoo.com/news/dwelling-deeper-intels-q2-earnings-111237911.html
#
# Intel, TI split leaves chip outlook in doubt
# https://finance.yahoo.com/news/intel-ti-split-leaves-chip-094834619.html
#
# Intel, TI split leaves chip outlook in doubt
# https://finance.yahoo.com/news/intel-ti-split-leaves-chip-094429196.html
#
# Twitter, Snap, Schlumberger Rise Premarket; Intel Falls
# https://finance.yahoo.com/news/twitter-snap-schlumberger-rise-premarket-080408235.html
#
# Intel Shares Slump as Muted 2021 Forecast, Margins Cloud Solid Earnings
# https://www.thestreet.com/investing/intel-shares-slump-as-muted-2021-forecast-clouds-solid-earnings?puc=yahoo&cm_ven=YAHOO
#
# Intel (INTC) Q2 2021 Earnings Call Transcript
# https://www.fool.com/earnings/call-transcripts/2021/07/23/intel-intc-q2-2021-earnings-call-transcript/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article
#
# Intel Falls As Forecast Underwhelms, Chip Shortage Could Prolong
# https://finance.yahoo.com/news/intel-falls-forecast-underwhelms-chip-054636960.html
#
# Snap, Twitter, Intel, Honeywell, American Express - 5 Things You Must Know Friday
# https://www.thestreet.com/markets/5-things-you-must-know-before-market-opens-friday-072321?puc=yahoo&cm_ven=YAHOO
#
# Intel appears to be feeling the competitive heat from AMD
# https://www.marketwatch.com/story/intel-appears-to-be-feeling-the-competitive-heat-from-amd-11627004561?siteid=yhoof2
#
# Intel CEO Says Global Chip Shortage Will Get Worse Before It Gets Better
# https://www.barrons.com/articles/intel-earnings-global-chip-shortage-51626998346?siteid=yhoof2
#
# Intel says chip shortage could drag into 2023 as outlook barely clears Street view
# https://www.marketwatch.com/story/intel-stock-ticks-lower-as-outlook-barely-clears-wall-street-expectations-following-beat-11626985199?siteid=yhoof2
#
# Intel Beats, Twitter & Snap Crush Estimates
# https://finance.yahoo.com/news/intel-beats-twitter-snap-crush-214309358.html
#
# Intel stocks rises after positive Q2 earnings
# https://finance.yahoo.com/video/intel-stocks-rises-positive-q2-212759733.html
#
# Intel (INTC) Tops Q2 Earnings and Revenue Estimates
# https://finance.yahoo.com/news/intel-intc-tops-q2-earnings-212009632.html
#
# Intels Sales Forecast Falls Short as Data Center Unit Sags
# https://finance.yahoo.com/news/intel-sales-forecast-falls-short-202829834.html
#
# Intel raises full-year sales forecast, but second-half demand worries send shares down
# https://finance.yahoo.com/news/intel-forecasts-current-quarter-revenue-201350914.html
#
# Chipmaker Intel raises annual revenue forecast
# https://finance.yahoo.com/news/chipmaker-intel-raises-annual-revenue-201038023.html
#
# UPDATE 4-Intel raises full-year sales forecast, but second-half demand worries send shares down
# https://finance.yahoo.com/news/1-chipmaker-intel-raises-annual-200812550.html
#
# Intel Arizona RISE Report: Our Commitment to Our Community and Corporate Responsibility
# https://finance.yahoo.com/news/intel-arizona-rise-report-commitment-184607598.html
#
# Intel Falls After Second-Quarter Earnings Beat, Tepid Guidance
# https://www.thestreet.com/investing/intel-falls-after-second-quarter-earnings-beat-tepid-guidance?puc=yahoo&cm_ven=YAHOO
#
# Dow Jones Falls On Surprise Jump In Jobless Claims; Snap, Twitter Set To Report Earnings
# https://www.investors.com/market-trend/stock-market-today/dow-jones-falls-on-surprise-jump-in-jobless-claims-snap-twitter-earnings-due/?src=A00220
#
# Texas Instruments tops estimates, but chip demand concerns linger
# https://finance.yahoo.com/video/texas-instruments-tops-estimates-chip-143641374.html
#
# Low Expectations Ahead of Intel Report
# https://finance.yahoo.com/news/low-expectations-ahead-intel-report-131624574.html
#
# Warning From Major Chipmaker Adds to Worries Industry Will Produce More Than Demand
# https://finance.yahoo.com/news/one-world-largest-chipmakers-worries-033935633.html
#
# Texas Instruments Forecast Stokes Concern Over Chip Demand
# https://finance.yahoo.com/news/texas-instruments-sales-forecast-stirs-202527038.html
#
# Intel Reports Earnings Today. Expectations Are High.
# https://www.barrons.com/articles/intel-earnings-51626886116?siteid=yhoof2
#
# Chip Shortages, Jobless Claims, ECB, Musk Lifts Bitcoin  - What's Moving Markets
# https://finance.yahoo.com/news/chip-shortages-jobless-claims-ecb-063658686.html
#
# Intel's foundry ambitions could be slowed by lack of deal targets
# https://finance.yahoo.com/news/intels-foundry-ambitions-could-slowed-213354344.html
